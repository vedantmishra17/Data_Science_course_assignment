# %%
#1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

Given:
Recurrence relation: 

T(n) = 3T(n-1) + 12n
T(0)=5

T(1) = 3T(1-1) + 12*1
T(1) = 3*T(0) + 12

we have to find the value of T(2):
    
    T(2) = 3T(2-1) + 12*2
    T(2) = 3*T(1) + 24
    T(2) = 3(3*T(0) + 12) + 24 # substituting the value of T(1)
    T(2) = 3(3*5 +12) + 24
    T(2) = 105
    
The value of T(2) is 105

# %%
2. Given a recurrence relation, solve it using the substitution method:
a. T(n) = T(n-1) + c
b. T(n) = 2T(n/2) + n
c. T(n) = 2T(n/2) + c
d. T(n) = T(n/2) + c


# a. T(n) = T(n-1) + c
# T(n) = T(n-1) + c = T(n-2) + c + c = T(n-3) + c + c + c = ... = T(n-k) + kc
# Base case: T(0) = b

# b. T(n) = 2T(n/2) + n
# T(n) = 2T(n/2) + n = 2(2T(n/4) + n/2) + n = 2^2T(n/2^2) + 2n = 2^3T(n/2^3) + 3n = ... = 2^kT(n/2^k) + kn
# Base case: T(1) = c

# c. T(n) = 2T(n/2) + c
# T(n) = 2T(n/2) + c = 2(2T(n/4) + c) + c = 2^2T(n/2^2) + 2c + c = 2^3T(n/2^3) + 4c + c = ... = 2^kT(n/2^k) + kc
# Base case: T(1) = c

# d. T(n) = T(n/2) + c
# T(n) = T(n/2) + c = T(n/4) + c + c = T(n/8) + c + c + c = ... = T(1) + log(n) * c
# Base case: T(1) = c

# %%
3. Given a recurrence relation, solve it using the recursive tree approach:
a. T(n) = 2T(n-1) +1
T(n) = 2T(n-1) + 1
     = 2[2T(n-2) + 1] + 1
     = 2^2T(n-2) + 2 + 1
     = 2^3T(n-3) + 2^2 + 2 + 1
     ...
     = 2^kT(n-k) + 2^k - 1 + ... + 2^2 + 2 + 1

When n - k = 1 (base case),
T(1) = 2T(0) + 1 (assuming T(0) = 1 or any base case value)

If we substitute k = n - 1, we get:
T(n) = 2^nT(1) + 2^n - 1 + 2^(n-1) + ... + 2^2 + 2 + 1
     = 2^n * T(1) + (2^n - 1) + (2^n - 2) + ... + 2 + 1
     = 2^n * T(1) + (2^n - 1) * 2 / 1 (sum of first n terms of a geometric series)
     = 2^n * T(1) + 2^(n+1) - 2 - 2
     = 2^n * T(1) + 2^(n+1) - 4

        
        
b. T(n) = 2T(n/2) + n
T(n) = 2T(n/2) + n
     = 2[2T(n/4) + n/2] + n
     = 2^2T(n/4) + 2n/2 + n
     = 2^2T(n/4) + 3n/2
     ...
     = 2^kT(n/2^k) + kn/(2^(k-1))

When n/2^k = 1 (base case),
n = 2^k
k = log2(n)

T(1) = 1 (assuming T(1) = 1 or any base case value)

If we substitute k = log2(n), we get:
T(n) = 2^(log2(n)) * T(1) + n * log2(n)
     = n * T(1) + n * log2(n)
